# %% [markdown]
# <a href="https://colab.research.google.com/github/Wondav/Data-Analysis/blob/main/Exploratory_Data_Analysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## **Exploratory Data Analysis**
# ### Descriptive Analysis
# Exploring the attributes of the customers, how they interact with each other, and how they interact with the eligibility Status of the Customers

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
sns.set(color_codes=True)

# %%
data=pd.read_csv('/content/drive/MyDrive/Colab Notebooks/Data Analysis/data_cleaned.csv')
data.head()
# Out:
#    Gender  Married  Dependents  ...  Property_Area  Loan_Status   Loan_ID
# 0     1.0      0.0         0.0  ...            2.0          1.0  LP001002
# 1     1.0      1.0         1.0  ...            0.0          0.0  LP001003
# 2     1.0      1.0         0.0  ...            2.0          1.0  LP001005
# 3     1.0      1.0         0.0  ...            2.0          1.0  LP001006
# 4     1.0      0.0         0.0  ...            2.0          1.0  LP001008
#
# [5 rows x 13 columns]

# %%
data['Gender']=data['Gender'].map({1:'Male',0:'Female'}, na_action=None)
data['Education']=data['Education'].map({1:'Graduate',0:'Not Graduate'}, na_action=None)
data['Married']=data['Married'].map({1:'Yes',0:'No'}, na_action=None)
data['Self_Employed']=data['Self_Employed'].map({1:'Yes',0:'No'}, na_action=None)
data['Property_Area']=data['Property_Area'].map({0:'Rural',1:'Semiurban',2:'Urban'}, na_action=None)
data['Loan_Status']=data['Loan_Status'].map({1:'Y',0:'N'}, na_action=None)
data['Dependents']=data['Dependents'].map({0:'0',1:'1',2:'2',3:'3+'}, na_action=None)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 614 entries, 0 to 613
# Data columns (total 13 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Gender             614 non-null    object
#  1   Married            614 non-null    object
#  2   Dependents         614 non-null    object
#  3   Education          614 non-null    object
#  4   Self_Employed      614 non-null    object
#  5   ApplicantIncome    614 non-null    float64
#  6   CoapplicantIncome  614 non-null    float64
#  7   LoanAmount         614 non-null    float64
#  8   Loan_Amount_Term   614 non-null    float64
#  9   Credit_History     614 non-null    float64
#  10  Property_Area      614 non-null    object
#  11  Loan_Status        614 non-null    object
#  12  Loan_ID            614 non-null    object
# dtypes: float64(5), object(8)
# memory usage: 62.5+ KB

# %% [markdown]
# **Univariate Analysis**\
# Exploring the attributes singularly

# %%
sns.histplot(data['ApplicantIncome'],color='indigo').set_title('Distribution of Customers Income')
plt.show()

# %%
sns.histplot(data['CoapplicantIncome'],color='indigo').set_title("Distribution of Customer's Coapplicant Income")
plt.show()

# %%
sns.histplot(data['LoanAmount'],color='indigo').set_title("Distribution of Customer's Loan")
plt.show()

# %%
sns.histplot(data['Loan_Amount_Term'],color='indigo').set_title("Distribution of Customer's Loan Term")
plt.show()

# %%
sns.countplot(x='Gender',data=data,palette='magma').set_title('Distribution of Customers Gender')
plt.show()

# %%
sns.countplot(x='Married',data=data,palette='magma').set_title("Distribution of Customer's Marriage Status")
plt.show()

# %%
sns.countplot(x='Self_Employed',data=data,palette='magma').set_title("Distribution of Customer's Employment Status")
plt.show()

# %%
sns.countplot(x='Education',data=data,palette='magma').set_title("Distribution of Customer's Education Status")
plt.show()

# %%
sns.countplot(x='Credit_History',data=data,palette='magma').set_title("Distribution of Customer's Credit History")
plt.show()

# %%
sns.countplot(x='Dependents',data=data,palette='magma').set_title("Distribution of Customer's No. of Dependents")
plt.show()

# %%
sns.countplot(x='Property_Area',data=data,palette='magma').set_title("Distribution of Customer's Property Area")
plt.show()

# %% [markdown]
# **Bivariate Analysis**\
# Exploring Relationship between attributes and Loan Status

# %%
sns.boxplot(x='Loan_Status',y='LoanAmount',data=data).set_title('Relationship Between Loan Amount and Loan Status')
plt.show()

# %%
sns.boxplot(x='Loan_Status',y='ApplicantIncome',data=data).set_title("Relationship Between Applicant's Income and Loan Status")
plt.show()

# %%
sns.boxplot(x='Loan_Status',y='CoapplicantIncome',data=data).set_title("Relationship Between Coapplicant's Income and Loan Status")
plt.show()

# %%
ct=pd.crosstab(data['Loan_Status'],data['Married'])
ax = ct.plot(kind='bar', stacked=True,figsize=(4,4)).set_title('Relationship Marriage Status and Loan Status')

# %%
ct=pd.crosstab(data['Loan_Status'],data['Gender'])
ax = ct.plot(kind='bar', stacked=True,figsize=(4,4)).set_title("Relationship Between Gender and Loan Status")

# %%
ct=pd.crosstab(data['Loan_Status'],data['Dependents'])
ax = ct.plot(kind='bar', stacked=True,figsize=(4,4)).set_title("Relationship Between No. of Dependents and Loan Status")

# %%
ct=pd.crosstab(data['Loan_Status'],data['Self_Employed'])
ax = ct.plot(kind='bar', stacked=True,figsize=(4,4)).set_title("Relationship Between Employment Status and Loan Status")

# %%
ct=pd.crosstab(data['Loan_Status'],data['Education'])
ax = ct.plot(kind='bar', stacked=True,figsize=(4,4)).set_title("Relationship Between Education Status and Loan Status")

# %%
ct=pd.crosstab(data['Loan_Status'],data['Credit_History'])
ax = ct.plot(kind='bar', stacked=True,figsize=(4,4)).set_title("Relatiionship Between Credit History and Loan Status")

# %%
ct=pd.crosstab(data['Loan_Status'],data['Property_Area'])
ax = ct.plot(kind='bar', stacked=True,figsize=(4,4)).set_title("Relationship Between Property Area and Loan Status")

# %% [markdown]
# ### **Summary**
# From the data we can tell that interviewed customer's:
# 1. income lies majorly between 2000 and 6000
# 2. Loan lies majorly between 50 and 250
# 3. are mostly male
# 4. are mostly employees
# 5. are mostly graduates
# 6. mostly have no dependents\
# We can also tell that there is a relationship between
# 7. Loan Amount and Loan Status
# 8. Credit History and Loan Status
